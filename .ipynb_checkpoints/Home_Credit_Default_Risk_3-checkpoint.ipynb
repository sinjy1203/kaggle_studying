# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

import warnings
warnings.filterwarnings('ignore')

# %%
NFOLDS = 3
SEED = 0
NROWS = None

# %% [markdown]
# ## data preprocessing

# %%
from pathlib import Path
data_dir = Path('C:/Users/sinjy/jupyter_notebook/datasets/kaggle_datasets/Home-Credit-Default-Risk_dataset')

data = pd.read_csv(data_dir / 'application_train.csv')
test = pd.read_csv(data_dir / 'application_test.csv')
prev = pd.read_csv(data_dir / 'previous_application.csv')

# %%
categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])

# %%
gc.enable()
y_train = data['TARGET']
del data['TARGET']

# %%
prev.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR NAME_CONTRACT_TYPE  AMT_ANNUITY  AMT_APPLICATION  \
# 0     2030495      271877     Consumer loans     1730.430          17145.0
# 1     2802425      108129         Cash loans    25188.615         607500.0
# 2     2523466      122040         Cash loans    15060.735         112500.0
# 3     2819243      176158         Cash loans    47041.335         450000.0
# 4     1784265      202054         Cash loans    31924.395         337500.0
#
#    AMT_CREDIT  AMT_DOWN_PAYMENT  AMT_GOODS_PRICE WEEKDAY_APPR_PROCESS_START  \
# 0     17145.0               0.0          17145.0                   SATURDAY
# 1    679671.0               NaN         607500.0                   THURSDAY
# 2    136444.5               NaN         112500.0                    TUESDAY
# 3    470790.0               NaN         450000.0                     MONDAY
# 4    404055.0               NaN         337500.0                   THURSDAY
#
#    HOUR_APPR_PROCESS_START  ... NAME_SELLER_INDUSTRY  CNT_PAYMENT  \
# 0                       15  ...         Connectivity         12.0
# 1                       11  ...                  XNA         36.0
# 2                       11  ...                  XNA         12.0
# 3                        7  ...                  XNA         12.0
# 4                        9  ...                  XNA         24.0
#
#    NAME_YIELD_GROUP       PRODUCT_COMBINATION  DAYS_FIRST_DRAWING  \
# 0            middle  POS mobile with interest            365243.0
# 1        low_action          Cash X-Sell: low            365243.0
# 2              high         Cash X-Sell: high            365243.0
# 3            middle       Cash X-Sell: middle            365243.0
# 4              high         Cash Street: high                 NaN
#
#   DAYS_FIRST_DUE DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE DAYS_TERMINATION  \
# 0          -42.0                     300.0          -42.0            -37.0
# 1         -134.0                     916.0       365243.0         365243.0
# 2         -271.0                      59.0       365243.0         365243.0
# 3         -482.0                    -152.0         -182.0           -177.0
# 4            NaN                       NaN            NaN              NaN
#
#   NFLAG_INSURED_ON_APPROVAL
# 0                       0.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       NaN
#
# [5 rows x 37 columns]

# %%
prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])
    
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test = x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

# %%
excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits=NFOLDS, shuffle=True, random_state=SEED)

# %% [markdown]
# ## model

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]
    
class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
    
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]

class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)
    
    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)
        
    def predict(self, x):
        return self.clf.predict_proba(x)[:, 1]
    
class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)
        
    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)
        
    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain, ))
    oof_test = np.zeros((ntest, ))
    oof_test_skf = np.empty((NFOLDS, ntest))
    
    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]
        
        clf.train(x_tr, y_tr)
        
        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)
        
    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': -1,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2
}

rf_params = {
    'n_jobs': -1,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds':200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators': 200,
    'learning_rate': 0.1,
    'num_leaves': 123,
    'colsample_bytree': 0.8,
    'subsample': 0.9,
    'max_depth': 15,
    'reg_alpha': 0.1,
    'reg_lambda': 0.1,
    'min_split_gain': 0.01,
    'min_child_weight': 2
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf=CatBoostClassifier, seed=SEED, params=catboost_params)
lg = LightGBMWrapper(clf=LGBMClassifier, seed=SEED, params=lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
lg_oof_train, lg_oof_test = get_oof(lg)

print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("CB-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
print("LG-CV: {}".format(sqrt(mean_squared_error(y_train, lg_oof_train))))
# Out:
# [13:24:00] WARNING: ..\src\learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:24:00] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:24:51] WARNING: ..\src\learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:24:52] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [13:25:45] WARNING: ..\src\learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [13:25:45] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0:	total: 231ms	remaining: 45.9s
# 1:	total: 303ms	remaining: 30s
# 2:	total: 358ms	remaining: 23.5s
# 3:	total: 403ms	remaining: 19.8s
# 4:	total: 434ms	remaining: 16.9s
# 5:	total: 467ms	remaining: 15.1s
# 6:	total: 498ms	remaining: 13.7s
# 7:	total: 524ms	remaining: 12.6s
# 8:	total: 554ms	remaining: 11.7s
# 9:	total: 589ms	remaining: 11.2s
# 10:	total: 620ms	remaining: 10.7s
# 11:	total: 650ms	remaining: 10.2s
# 12:	total: 686ms	remaining: 9.87s
# 13:	total: 718ms	remaining: 9.54s
# 14:	total: 749ms	remaining: 9.23s
# 15:	total: 780ms	remaining: 8.96s
# 16:	total: 808ms	remaining: 8.7s
# 17:	total: 835ms	remaining: 8.44s
# 18:	total: 861ms	remaining: 8.21s
# 19:	total: 891ms	remaining: 8.02s
# 20:	total: 919ms	remaining: 7.83s
# 21:	total: 946ms	remaining: 7.65s
# 22:	total: 979ms	remaining: 7.54s
# 23:	total: 1.01s	remaining: 7.44s
# 24:	total: 1.04s	remaining: 7.31s
# 25:	total: 1.08s	remaining: 7.21s
# 26:	total: 1.11s	remaining: 7.11s
# 27:	total: 1.14s	remaining: 6.98s
# 28:	total: 1.17s	remaining: 6.88s
# 29:	total: 1.2s	remaining: 6.78s
# 30:	total: 1.22s	remaining: 6.66s
# 31:	total: 1.25s	remaining: 6.56s
# 32:	total: 1.28s	remaining: 6.46s
# 33:	total: 1.31s	remaining: 6.38s
# 34:	total: 1.33s	remaining: 6.29s
# 35:	total: 1.36s	remaining: 6.2s
# 36:	total: 1.39s	remaining: 6.14s
# 37:	total: 1.42s	remaining: 6.07s
# 38:	total: 1.45s	remaining: 6s
# 39:	total: 1.49s	remaining: 5.95s
# 40:	total: 1.52s	remaining: 5.89s
# 41:	total: 1.55s	remaining: 5.82s
# 42:	total: 1.58s	remaining: 5.76s
# 43:	total: 1.61s	remaining: 5.71s
# 44:	total: 1.64s	remaining: 5.65s
# 45:	total: 1.67s	remaining: 5.6s
# 46:	total: 1.71s	remaining: 5.55s
# 47:	total: 1.74s	remaining: 5.5s
# 48:	total: 1.76s	remaining: 5.43s
# 49:	total: 1.79s	remaining: 5.37s
# 50:	total: 1.82s	remaining: 5.31s
# 51:	total: 1.85s	remaining: 5.26s
# 52:	total: 1.88s	remaining: 5.22s
# 53:	total: 1.91s	remaining: 5.17s
# 54:	total: 1.94s	remaining: 5.11s
# 55:	total: 1.97s	remaining: 5.06s
# 56:	total: 2s	remaining: 5.02s
# 57:	total: 2.03s	remaining: 4.97s
# 58:	total: 2.06s	remaining: 4.92s
# 59:	total: 2.08s	remaining: 4.87s
# 60:	total: 2.12s	remaining: 4.82s
# 61:	total: 2.15s	remaining: 4.78s
# 62:	total: 2.17s	remaining: 4.73s
# 63:	total: 2.2s	remaining: 4.68s
# 64:	total: 2.23s	remaining: 4.64s
# 65:	total: 2.26s	remaining: 4.6s
# 66:	total: 2.29s	remaining: 4.55s
# 67:	total: 2.32s	remaining: 4.51s
# 68:	total: 2.35s	remaining: 4.47s
# 69:	total: 2.38s	remaining: 4.42s
# 70:	total: 2.42s	remaining: 4.39s
# 71:	total: 2.45s	remaining: 4.36s
# 72:	total: 2.48s	remaining: 4.31s
# 73:	total: 2.51s	remaining: 4.27s
# 74:	total: 2.54s	remaining: 4.24s
# 75:	total: 2.58s	remaining: 4.2s
# 76:	total: 2.6s	remaining: 4.16s
# 77:	total: 2.63s	remaining: 4.11s
# 78:	total: 2.66s	remaining: 4.07s
# 79:	total: 2.69s	remaining: 4.03s
# 80:	total: 2.72s	remaining: 4s
# 81:	total: 2.75s	remaining: 3.96s
# 82:	total: 2.79s	remaining: 3.93s
# 83:	total: 2.82s	remaining: 3.89s
# 84:	total: 2.85s	remaining: 3.86s
# 85:	total: 2.88s	remaining: 3.82s
# 86:	total: 2.91s	remaining: 3.78s
# 87:	total: 2.94s	remaining: 3.74s
# 88:	total: 2.97s	remaining: 3.71s
# 89:	total: 3s	remaining: 3.67s
# 90:	total: 3.04s	remaining: 3.64s
# 91:	total: 3.07s	remaining: 3.6s
# 92:	total: 3.1s	remaining: 3.56s
# 93:	total: 3.12s	remaining: 3.52s
# 94:	total: 3.15s	remaining: 3.48s
# 95:	total: 3.18s	remaining: 3.45s
# 96:	total: 3.21s	remaining: 3.41s
# 97:	total: 3.24s	remaining: 3.38s
# 98:	total: 3.27s	remaining: 3.34s
# 99:	total: 3.3s	remaining: 3.3s
# 100:	total: 3.33s	remaining: 3.27s
# 101:	total: 3.36s	remaining: 3.23s
# 102:	total: 3.39s	remaining: 3.2s
# 103:	total: 3.42s	remaining: 3.16s
# 104:	total: 3.45s	remaining: 3.12s
# 105:	total: 3.48s	remaining: 3.08s
# 106:	total: 3.5s	remaining: 3.05s
# 107:	total: 3.53s	remaining: 3.01s
# 108:	total: 3.56s	remaining: 2.98s
# 109:	total: 3.59s	remaining: 2.94s
# 110:	total: 3.62s	remaining: 2.9s
# 111:	total: 3.65s	remaining: 2.87s
# 112:	total: 3.69s	remaining: 2.84s
# 113:	total: 3.71s	remaining: 2.8s
# 114:	total: 3.74s	remaining: 2.77s
# 115:	total: 3.77s	remaining: 2.73s
# 116:	total: 3.8s	remaining: 2.69s
# 117:	total: 3.82s	remaining: 2.66s
# 118:	total: 3.86s	remaining: 2.63s
# 119:	total: 3.89s	remaining: 2.59s
# 120:	total: 3.92s	remaining: 2.56s
# 121:	total: 3.95s	remaining: 2.52s
# 122:	total: 3.98s	remaining: 2.49s
# 123:	total: 4.01s	remaining: 2.46s
# 124:	total: 4.04s	remaining: 2.43s
# 125:	total: 4.08s	remaining: 2.4s
# 126:	total: 4.11s	remaining: 2.36s
# 127:	total: 4.14s	remaining: 2.33s
# 128:	total: 4.17s	remaining: 2.3s
# 129:	total: 4.2s	remaining: 2.26s
# 130:	total: 4.23s	remaining: 2.23s
# 131:	total: 4.26s	remaining: 2.19s
# 132:	total: 4.29s	remaining: 2.16s
# 133:	total: 4.32s	remaining: 2.13s
# 134:	total: 4.35s	remaining: 2.09s
# 135:	total: 4.38s	remaining: 2.06s
# 136:	total: 4.41s	remaining: 2.03s
# 137:	total: 4.45s	remaining: 2s
# 138:	total: 4.47s	remaining: 1.96s
# 139:	total: 4.5s	remaining: 1.93s
# 140:	total: 4.53s	remaining: 1.9s
# 141:	total: 4.56s	remaining: 1.86s
# 142:	total: 4.6s	remaining: 1.83s
# 143:	total: 4.62s	remaining: 1.8s
# 144:	total: 4.65s	remaining: 1.76s
# 145:	total: 4.68s	remaining: 1.73s
# 146:	total: 4.71s	remaining: 1.7s
# 147:	total: 4.74s	remaining: 1.67s
# 148:	total: 4.77s	remaining: 1.63s
# 149:	total: 4.81s	remaining: 1.6s
# 150:	total: 4.83s	remaining: 1.57s
# 151:	total: 4.86s	remaining: 1.53s
# 152:	total: 4.89s	remaining: 1.5s
# 153:	total: 4.92s	remaining: 1.47s
# 154:	total: 4.95s	remaining: 1.44s
# 155:	total: 4.98s	remaining: 1.4s
# 156:	total: 5.01s	remaining: 1.37s
# 157:	total: 5.04s	remaining: 1.34s
# 158:	total: 5.07s	remaining: 1.31s
# 159:	total: 5.1s	remaining: 1.27s
# 160:	total: 5.13s	remaining: 1.24s
# 161:	total: 5.16s	remaining: 1.21s
# 162:	total: 5.19s	remaining: 1.18s
# 163:	total: 5.22s	remaining: 1.15s
# 164:	total: 5.25s	remaining: 1.11s
# 165:	total: 5.28s	remaining: 1.08s
# 166:	total: 5.3s	remaining: 1.05s
# 167:	total: 5.33s	remaining: 1.01s
# 168:	total: 5.36s	remaining: 983ms
# 169:	total: 5.39s	remaining: 952ms
# 170:	total: 5.43s	remaining: 920ms
# 171:	total: 5.45s	remaining: 888ms
# 172:	total: 5.49s	remaining: 857ms
# 173:	total: 5.52s	remaining: 825ms
# 174:	total: 5.55s	remaining: 792ms
# 175:	total: 5.58s	remaining: 761ms
# 176:	total: 5.61s	remaining: 729ms
# 177:	total: 5.63s	remaining: 697ms
# 178:	total: 5.67s	remaining: 665ms
# 179:	total: 5.7s	remaining: 633ms
# 180:	total: 5.73s	remaining: 601ms
# 181:	total: 5.75s	remaining: 569ms
# 182:	total: 5.79s	remaining: 537ms
# 183:	total: 5.82s	remaining: 506ms
# 184:	total: 5.85s	remaining: 475ms
# 185:	total: 5.88s	remaining: 443ms
# 186:	total: 5.92s	remaining: 411ms
# 187:	total: 5.96s	remaining: 380ms
# 188:	total: 5.99s	remaining: 348ms
# 189:	total: 6.02s	remaining: 317ms
# 190:	total: 6.05s	remaining: 285ms
# 191:	total: 6.08s	remaining: 253ms
# 192:	total: 6.11s	remaining: 222ms
# 193:	total: 6.14s	remaining: 190ms
# 194:	total: 6.17s	remaining: 158ms
# 195:	total: 6.19s	remaining: 126ms
# 196:	total: 6.23s	remaining: 94.9ms
# 197:	total: 6.26s	remaining: 63.2ms
# 198:	total: 6.29s	remaining: 31.6ms
# 199:	total: 6.32s	remaining: 0us
# 0:	total: 38.3ms	remaining: 7.63s
# 1:	total: 70.2ms	remaining: 6.95s
# 2:	total: 100ms	remaining: 6.58s
# 3:	total: 130ms	remaining: 6.36s
# 4:	total: 164ms	remaining: 6.38s
# 5:	total: 199ms	remaining: 6.44s
# 6:	total: 230ms	remaining: 6.34s
# 7:	total: 262ms	remaining: 6.3s
# 8:	total: 297ms	remaining: 6.31s
# 9:	total: 324ms	remaining: 6.15s
# 10:	total: 352ms	remaining: 6.05s
# 11:	total: 385ms	remaining: 6.03s
# 12:	total: 421ms	remaining: 6.05s
# 13:	total: 459ms	remaining: 6.09s
# 14:	total: 487ms	remaining: 6s
# 15:	total: 517ms	remaining: 5.95s
# 16:	total: 545ms	remaining: 5.87s
# 17:	total: 578ms	remaining: 5.84s
# 18:	total: 609ms	remaining: 5.8s
# 19:	total: 639ms	remaining: 5.75s
# 20:	total: 668ms	remaining: 5.69s
# 21:	total: 703ms	remaining: 5.69s
# 22:	total: 738ms	remaining: 5.68s
# 23:	total: 768ms	remaining: 5.63s
# 24:	total: 802ms	remaining: 5.61s
# 25:	total: 830ms	remaining: 5.56s
# 26:	total: 863ms	remaining: 5.53s
# 27:	total: 898ms	remaining: 5.52s
# 28:	total: 926ms	remaining: 5.46s
# 29:	total: 954ms	remaining: 5.4s
# 30:	total: 986ms	remaining: 5.38s
# 31:	total: 1.02s	remaining: 5.34s
# 32:	total: 1.05s	remaining: 5.3s
# 33:	total: 1.08s	remaining: 5.27s
# 34:	total: 1.11s	remaining: 5.23s
# 35:	total: 1.14s	remaining: 5.18s
# 36:	total: 1.17s	remaining: 5.15s
# 37:	total: 1.2s	remaining: 5.12s
# 38:	total: 1.23s	remaining: 5.07s
# 39:	total: 1.25s	remaining: 5.02s
# 40:	total: 1.29s	remaining: 5s
# 41:	total: 1.32s	remaining: 4.97s
# 42:	total: 1.35s	remaining: 4.94s
# 43:	total: 1.38s	remaining: 4.9s
# 44:	total: 1.41s	remaining: 4.87s
# 45:	total: 1.44s	remaining: 4.83s
# 46:	total: 1.47s	remaining: 4.79s
# 47:	total: 1.5s	remaining: 4.76s
# 48:	total: 1.53s	remaining: 4.72s
# 49:	total: 1.56s	remaining: 4.68s
# 50:	total: 1.59s	remaining: 4.64s
# 51:	total: 1.62s	remaining: 4.61s
# 52:	total: 1.65s	remaining: 4.57s
# 53:	total: 1.68s	remaining: 4.54s
# 54:	total: 1.71s	remaining: 4.51s
# 55:	total: 1.74s	remaining: 4.48s
# 56:	total: 1.77s	remaining: 4.44s
# 57:	total: 1.8s	remaining: 4.41s
# 58:	total: 1.83s	remaining: 4.38s
# 59:	total: 1.87s	remaining: 4.36s
# 60:	total: 1.9s	remaining: 4.33s
# 61:	total: 1.93s	remaining: 4.3s
# 62:	total: 1.96s	remaining: 4.27s
# 63:	total: 1.99s	remaining: 4.23s
# 64:	total: 2.03s	remaining: 4.21s
# 65:	total: 2.06s	remaining: 4.17s
# 66:	total: 2.08s	remaining: 4.14s
# 67:	total: 2.12s	remaining: 4.11s
# 68:	total: 2.15s	remaining: 4.08s
# 69:	total: 2.18s	remaining: 4.04s
# 70:	total: 2.21s	remaining: 4.01s
# 71:	total: 2.24s	remaining: 3.99s
# 72:	total: 2.27s	remaining: 3.95s
# 73:	total: 2.3s	remaining: 3.92s
# 74:	total: 2.33s	remaining: 3.89s
# 75:	total: 2.36s	remaining: 3.86s
# 76:	total: 2.39s	remaining: 3.82s
# 77:	total: 2.43s	remaining: 3.79s
# 78:	total: 2.45s	remaining: 3.76s
# 79:	total: 2.48s	remaining: 3.72s
# 80:	total: 2.51s	remaining: 3.69s
# 81:	total: 2.54s	remaining: 3.65s
# 82:	total: 2.57s	remaining: 3.62s
# 83:	total: 2.59s	remaining: 3.58s
# 84:	total: 2.62s	remaining: 3.55s
# 85:	total: 2.65s	remaining: 3.52s
# 86:	total: 2.68s	remaining: 3.49s
# 87:	total: 2.72s	remaining: 3.46s
# 88:	total: 2.75s	remaining: 3.43s
# 89:	total: 2.79s	remaining: 3.41s
# 90:	total: 2.82s	remaining: 3.38s
# 91:	total: 2.85s	remaining: 3.35s
# 92:	total: 2.88s	remaining: 3.31s
# 93:	total: 2.9s	remaining: 3.27s
# 94:	total: 2.94s	remaining: 3.25s
# 95:	total: 2.96s	remaining: 3.21s
# 96:	total: 2.99s	remaining: 3.18s
# 97:	total: 3.02s	remaining: 3.14s
# 98:	total: 3.05s	remaining: 3.11s
# 99:	total: 3.08s	remaining: 3.08s
# 100:	total: 3.11s	remaining: 3.05s
# 101:	total: 3.14s	remaining: 3.02s
# 102:	total: 3.17s	remaining: 2.99s
# 103:	total: 3.2s	remaining: 2.95s
# 104:	total: 3.23s	remaining: 2.92s
# 105:	total: 3.26s	remaining: 2.89s
# 106:	total: 3.29s	remaining: 2.86s
# 107:	total: 3.32s	remaining: 2.83s
# 108:	total: 3.35s	remaining: 2.8s
# 109:	total: 3.38s	remaining: 2.77s
# 110:	total: 3.41s	remaining: 2.74s
# 111:	total: 3.45s	remaining: 2.71s
# 112:	total: 3.48s	remaining: 2.68s
# 113:	total: 3.52s	remaining: 2.65s
# 114:	total: 3.55s	remaining: 2.62s
# 115:	total: 3.57s	remaining: 2.59s
# 116:	total: 3.6s	remaining: 2.56s
# 117:	total: 3.63s	remaining: 2.52s
# 118:	total: 3.66s	remaining: 2.49s
# 119:	total: 3.7s	remaining: 2.46s
# 120:	total: 3.72s	remaining: 2.43s
# 121:	total: 3.76s	remaining: 2.4s
# 122:	total: 3.79s	remaining: 2.37s
# 123:	total: 3.81s	remaining: 2.34s
# 124:	total: 3.85s	remaining: 2.31s
# 125:	total: 3.88s	remaining: 2.28s
# 126:	total: 3.91s	remaining: 2.25s
# 127:	total: 3.94s	remaining: 2.21s
# 128:	total: 3.97s	remaining: 2.18s
# 129:	total: 4s	remaining: 2.15s
# 130:	total: 4.03s	remaining: 2.12s
# 131:	total: 4.05s	remaining: 2.09s
# 132:	total: 4.08s	remaining: 2.06s
# 133:	total: 4.11s	remaining: 2.02s
# 134:	total: 4.14s	remaining: 1.99s
# 135:	total: 4.17s	remaining: 1.96s
# 136:	total: 4.2s	remaining: 1.93s
# 137:	total: 4.23s	remaining: 1.9s
# 138:	total: 4.26s	remaining: 1.87s
# 139:	total: 4.3s	remaining: 1.84s
# 140:	total: 4.33s	remaining: 1.81s
# 141:	total: 4.37s	remaining: 1.78s
# 142:	total: 4.4s	remaining: 1.75s
# 143:	total: 4.43s	remaining: 1.72s
# 144:	total: 4.46s	remaining: 1.69s
# 145:	total: 4.49s	remaining: 1.66s
# 146:	total: 4.52s	remaining: 1.63s
# 147:	total: 4.55s	remaining: 1.6s
# 148:	total: 4.58s	remaining: 1.57s
# 149:	total: 4.62s	remaining: 1.54s
# 150:	total: 4.65s	remaining: 1.51s
# 151:	total: 4.68s	remaining: 1.48s
# 152:	total: 4.71s	remaining: 1.45s
# 153:	total: 4.74s	remaining: 1.42s
# 154:	total: 4.77s	remaining: 1.38s
# 155:	total: 4.8s	remaining: 1.35s
# 156:	total: 4.83s	remaining: 1.32s
# 157:	total: 4.86s	remaining: 1.29s
# 158:	total: 4.89s	remaining: 1.26s
# 159:	total: 4.92s	remaining: 1.23s
# 160:	total: 4.95s	remaining: 1.2s
# 161:	total: 4.98s	remaining: 1.17s
# 162:	total: 5.01s	remaining: 1.14s
# 163:	total: 5.04s	remaining: 1.11s
# 164:	total: 5.07s	remaining: 1.07s
# 165:	total: 5.1s	remaining: 1.04s
# 166:	total: 5.13s	remaining: 1.01s
# 167:	total: 5.16s	remaining: 982ms
# 168:	total: 5.18s	remaining: 951ms
# 169:	total: 5.21s	remaining: 920ms
# 170:	total: 5.24s	remaining: 889ms
# 171:	total: 5.28s	remaining: 859ms
# 172:	total: 5.3s	remaining: 828ms
# 173:	total: 5.33s	remaining: 797ms
# 174:	total: 5.36s	remaining: 766ms
# 175:	total: 5.39s	remaining: 735ms
# 176:	total: 5.43s	remaining: 705ms
# 177:	total: 5.45s	remaining: 674ms
# 178:	total: 5.48s	remaining: 643ms
# 179:	total: 5.51s	remaining: 613ms
# 180:	total: 5.54s	remaining: 582ms
# 181:	total: 5.58s	remaining: 552ms
# 182:	total: 5.61s	remaining: 521ms
# 183:	total: 5.64s	remaining: 490ms
# 184:	total: 5.67s	remaining: 459ms
# 185:	total: 5.7s	remaining: 429ms
# 186:	total: 5.73s	remaining: 398ms
# 187:	total: 5.75s	remaining: 367ms
# 188:	total: 5.78s	remaining: 336ms
# 189:	total: 5.81s	remaining: 306ms
# 190:	total: 5.84s	remaining: 275ms
# 191:	total: 5.87s	remaining: 245ms
# 192:	total: 5.91s	remaining: 214ms
# 193:	total: 5.94s	remaining: 184ms
# 194:	total: 5.96s	remaining: 153ms
# 195:	total: 6s	remaining: 122ms
# 196:	total: 6.03s	remaining: 91.9ms
# 197:	total: 6.07s	remaining: 61.3ms
# 198:	total: 6.09s	remaining: 30.6ms
# 199:	total: 6.13s	remaining: 0us
# 0:	total: 33.7ms	remaining: 6.71s
# 1:	total: 65.1ms	remaining: 6.45s
# 2:	total: 95.5ms	remaining: 6.27s
# 3:	total: 129ms	remaining: 6.3s
# 4:	total: 161ms	remaining: 6.29s
# 5:	total: 192ms	remaining: 6.2s
# 6:	total: 220ms	remaining: 6.07s
# 7:	total: 253ms	remaining: 6.08s
# 8:	total: 291ms	remaining: 6.18s
# 9:	total: 321ms	remaining: 6.1s
# 10:	total: 354ms	remaining: 6.08s
# 11:	total: 385ms	remaining: 6.03s
# 12:	total: 412ms	remaining: 5.93s
# 13:	total: 442ms	remaining: 5.87s
# 14:	total: 476ms	remaining: 5.87s
# 15:	total: 503ms	remaining: 5.78s
# 16:	total: 532ms	remaining: 5.73s
# 17:	total: 558ms	remaining: 5.65s
# 18:	total: 589ms	remaining: 5.61s
# 19:	total: 619ms	remaining: 5.57s
# 20:	total: 649ms	remaining: 5.53s
# 21:	total: 684ms	remaining: 5.53s
# 22:	total: 716ms	remaining: 5.51s
# 23:	total: 748ms	remaining: 5.49s
# 24:	total: 779ms	remaining: 5.45s
# 25:	total: 808ms	remaining: 5.4s
# 26:	total: 836ms	remaining: 5.35s
# 27:	total: 866ms	remaining: 5.32s
# 28:	total: 896ms	remaining: 5.28s
# 29:	total: 923ms	remaining: 5.23s
# 30:	total: 953ms	remaining: 5.19s
# 31:	total: 985ms	remaining: 5.17s
# 32:	total: 1.01s	remaining: 5.13s
# 33:	total: 1.05s	remaining: 5.13s
# 34:	total: 1.08s	remaining: 5.1s
# 35:	total: 1.11s	remaining: 5.07s
# 36:	total: 1.15s	remaining: 5.05s
# 37:	total: 1.17s	remaining: 5.01s
# 38:	total: 1.21s	remaining: 4.99s
# 39:	total: 1.24s	remaining: 4.94s
# 40:	total: 1.27s	remaining: 4.93s
# 41:	total: 1.3s	remaining: 4.89s
# 42:	total: 1.33s	remaining: 4.85s
# 43:	total: 1.36s	remaining: 4.83s
# 44:	total: 1.39s	remaining: 4.79s
# 45:	total: 1.42s	remaining: 4.75s
# 46:	total: 1.45s	remaining: 4.72s
# 47:	total: 1.48s	remaining: 4.67s
# 48:	total: 1.5s	remaining: 4.64s
# 49:	total: 1.53s	remaining: 4.6s
# 50:	total: 1.56s	remaining: 4.57s
# 51:	total: 1.59s	remaining: 4.53s
# 52:	total: 1.62s	remaining: 4.5s
# 53:	total: 1.65s	remaining: 4.46s
# 54:	total: 1.68s	remaining: 4.43s
# 55:	total: 1.71s	remaining: 4.4s
# 56:	total: 1.74s	remaining: 4.37s
# 57:	total: 1.77s	remaining: 4.33s
# 58:	total: 1.8s	remaining: 4.31s
# 59:	total: 1.83s	remaining: 4.28s
# 60:	total: 1.86s	remaining: 4.25s
# 61:	total: 1.9s	remaining: 4.22s
# 62:	total: 1.92s	remaining: 4.18s
# 63:	total: 1.95s	remaining: 4.15s
# 64:	total: 1.98s	remaining: 4.12s
# 65:	total: 2.02s	remaining: 4.09s
# 66:	total: 2.05s	remaining: 4.06s
# 67:	total: 2.08s	remaining: 4.04s
# 68:	total: 2.11s	remaining: 4.01s
# 69:	total: 2.14s	remaining: 3.97s
# 70:	total: 2.17s	remaining: 3.94s
# 71:	total: 2.19s	remaining: 3.9s
# 72:	total: 2.23s	remaining: 3.87s
# 73:	total: 2.26s	remaining: 3.84s
# 74:	total: 2.29s	remaining: 3.81s
# 75:	total: 2.32s	remaining: 3.78s
# 76:	total: 2.35s	remaining: 3.76s
# 77:	total: 2.38s	remaining: 3.73s
# 78:	total: 2.41s	remaining: 3.69s
# 79:	total: 2.44s	remaining: 3.66s
# 80:	total: 2.47s	remaining: 3.63s
# 81:	total: 2.5s	remaining: 3.59s
# 82:	total: 2.52s	remaining: 3.56s
# 83:	total: 2.55s	remaining: 3.52s
# 84:	total: 2.58s	remaining: 3.5s
# 85:	total: 2.61s	remaining: 3.46s
# 86:	total: 2.64s	remaining: 3.43s
# 87:	total: 2.67s	remaining: 3.4s
# 88:	total: 2.7s	remaining: 3.37s
# 89:	total: 2.73s	remaining: 3.33s
# 90:	total: 2.76s	remaining: 3.3s
# 91:	total: 2.79s	remaining: 3.28s
# 92:	total: 2.83s	remaining: 3.25s
# 93:	total: 2.85s	remaining: 3.22s
# 94:	total: 2.89s	remaining: 3.19s
# 95:	total: 2.92s	remaining: 3.16s
# 96:	total: 2.95s	remaining: 3.13s
# 97:	total: 2.98s	remaining: 3.1s
# 98:	total: 3.01s	remaining: 3.07s
# 99:	total: 3.04s	remaining: 3.04s
# 100:	total: 3.06s	remaining: 3s
# 101:	total: 3.09s	remaining: 2.97s
# 102:	total: 3.12s	remaining: 2.94s
# 103:	total: 3.16s	remaining: 2.91s
# 104:	total: 3.19s	remaining: 2.89s
# 105:	total: 3.22s	remaining: 2.85s
# 106:	total: 3.25s	remaining: 2.83s
# 107:	total: 3.29s	remaining: 2.8s
# 108:	total: 3.32s	remaining: 2.77s
# 109:	total: 3.35s	remaining: 2.74s
# 110:	total: 3.38s	remaining: 2.71s
# 111:	total: 3.42s	remaining: 2.69s
# 112:	total: 3.45s	remaining: 2.66s
# 113:	total: 3.48s	remaining: 2.63s
# 114:	total: 3.51s	remaining: 2.59s
# 115:	total: 3.54s	remaining: 2.56s
# 116:	total: 3.57s	remaining: 2.53s
# 117:	total: 3.6s	remaining: 2.5s
# 118:	total: 3.63s	remaining: 2.47s
# 119:	total: 3.66s	remaining: 2.44s
# 120:	total: 3.69s	remaining: 2.41s
# 121:	total: 3.72s	remaining: 2.38s
# 122:	total: 3.75s	remaining: 2.35s
# 123:	total: 3.78s	remaining: 2.32s
# 124:	total: 3.81s	remaining: 2.29s
# 125:	total: 3.84s	remaining: 2.25s
# 126:	total: 3.87s	remaining: 2.23s
# 127:	total: 3.9s	remaining: 2.19s
# 128:	total: 3.93s	remaining: 2.16s
# 129:	total: 3.97s	remaining: 2.14s
# 130:	total: 4s	remaining: 2.11s
# 131:	total: 4.03s	remaining: 2.08s
# 132:	total: 4.06s	remaining: 2.04s
# 133:	total: 4.1s	remaining: 2.02s
# 134:	total: 4.12s	remaining: 1.99s
# 135:	total: 4.16s	remaining: 1.96s
# 136:	total: 4.19s	remaining: 1.93s
# 137:	total: 4.22s	remaining: 1.9s
# 138:	total: 4.25s	remaining: 1.87s
# 139:	total: 4.28s	remaining: 1.84s
# 140:	total: 4.31s	remaining: 1.8s
# 141:	total: 4.34s	remaining: 1.77s
# 142:	total: 4.37s	remaining: 1.74s
# 143:	total: 4.4s	remaining: 1.71s
# 144:	total: 4.43s	remaining: 1.68s
# 145:	total: 4.46s	remaining: 1.65s
# 146:	total: 4.49s	remaining: 1.62s
# 147:	total: 4.52s	remaining: 1.59s
# 148:	total: 4.55s	remaining: 1.56s
# 149:	total: 4.58s	remaining: 1.53s
# 150:	total: 4.61s	remaining: 1.5s
# 151:	total: 4.64s	remaining: 1.47s
# 152:	total: 4.67s	remaining: 1.43s
# 153:	total: 4.7s	remaining: 1.4s
# 154:	total: 4.73s	remaining: 1.37s
# 155:	total: 4.75s	remaining: 1.34s
# 156:	total: 4.78s	remaining: 1.31s
# 157:	total: 4.81s	remaining: 1.28s
# 158:	total: 4.84s	remaining: 1.25s
# 159:	total: 4.87s	remaining: 1.22s
# 160:	total: 4.9s	remaining: 1.19s
# 161:	total: 4.93s	remaining: 1.16s
# 162:	total: 4.96s	remaining: 1.13s
# 163:	total: 4.99s	remaining: 1.1s
# 164:	total: 5.02s	remaining: 1.06s
# 165:	total: 5.05s	remaining: 1.03s
# 166:	total: 5.08s	remaining: 1s
# 167:	total: 5.11s	remaining: 974ms
# 168:	total: 5.14s	remaining: 943ms
# 169:	total: 5.18s	remaining: 914ms
# 170:	total: 5.21s	remaining: 883ms
# 171:	total: 5.24s	remaining: 853ms
# 172:	total: 5.26s	remaining: 822ms
# 173:	total: 5.29s	remaining: 791ms
# 174:	total: 5.33s	remaining: 761ms
# 175:	total: 5.36s	remaining: 731ms
# 176:	total: 5.39s	remaining: 700ms
# 177:	total: 5.42s	remaining: 670ms
# 178:	total: 5.45s	remaining: 639ms
# 179:	total: 5.48s	remaining: 609ms
# 180:	total: 5.51s	remaining: 579ms
# 181:	total: 5.54s	remaining: 548ms
# 182:	total: 5.57s	remaining: 518ms
# 183:	total: 5.6s	remaining: 487ms
# 184:	total: 5.63s	remaining: 456ms
# 185:	total: 5.66s	remaining: 426ms
# 186:	total: 5.69s	remaining: 396ms
# 187:	total: 5.72s	remaining: 365ms
# 188:	total: 5.75s	remaining: 335ms
# 189:	total: 5.78s	remaining: 304ms
# 190:	total: 5.82s	remaining: 274ms
# 191:	total: 5.85s	remaining: 244ms
# 192:	total: 5.88s	remaining: 213ms
# 193:	total: 5.91s	remaining: 183ms
# 194:	total: 5.94s	remaining: 152ms
# 195:	total: 5.97s	remaining: 122ms
# 196:	total: 6s	remaining: 91.3ms
# 197:	total: 6.03s	remaining: 60.9ms
# 198:	total: 6.06s	remaining: 30.4ms
# 199:	total: 6.08s	remaining: 0us
# XG-CV: 0.25969546149690725
# ET-CV: 0.26296502347137407
# RF-CV: 0.2627260187688126
# CB-CV: 0.331012765614397
# LG-CV: 0.2612395722996374

# %%
predict_dir = Path('C:/Users/sinjy/jupyter_notebook/datasets/kaggle_predict')

x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train, lg_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test, lg_oof_test), axis=1)

print("{}, {}".format(x_train.shape, x_test.shape))

logistic_regression = LogisticRegression()
logistic_regression.fit(x_train, y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:, 1]
test[['SK_ID_CURR', 'TARGET']].to_csv(predict_dir / 'HomeCredit3.csv', index=False, float_format='%.8f')
# Out:
# (307511, 5), (48744, 5)

# %% [markdown]
# ## test score: 0.75815
